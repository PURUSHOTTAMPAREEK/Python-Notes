# %% [markdown]
# # Step 1

# %% [markdown]
# # Aurora and RDS

# %% [raw]
# Aurora and RDS
# --> Database
# --> Create database
# --> Engine options
#     --> { ✅ POSTgreSQL }
#     --> Tamplates
#     --> {✅ Free tier}
#     --> Master username --> postgres
#     --> Master Password  --> abcd12345
#     --> public access --> yes ✅
#     --> create database  🚀

# %% [markdown]
# # Step 2

# %% [markdown]
# # EC2

# %% [raw]
# EC2
# --> Launch instance
#     --> Name --> ramsita1
#     --> Quick Start --> ✅ Ubuntu
#     --> Instance Type --> t2.medium / c5.xlarge optional ✅
#     --> Key pair --> Docker-key ✅
#     --> Firewall
#           --> ✅ SSH
#           --> ✅ HTTPS
#           --> ✅ HTTP
#     --> Configure storage --> 20
#     --> Launch Instance 🚀 🔥🔥🔥
#     --> View all instances 🔥

# %% [markdown]
# # Step 3

# %% [raw]
# EC2
# --> instance
#    --> ramsita1
#       --> Connect
#           --> connect
# # open terminal Ubantu

# %% [markdown]
# ## 🏴‍☠️🏴‍☠️🏴‍☠️ --> Paste this command

# %% [raw]
# sudo apt-get update

# %% [raw]
# sudo apt-get install docker.io -y

# %% [raw]
# sudo usermod -aG docker $USER && newgrp docker

# %% [raw]
# git clone https://github.com/1602saurab/poster.git

# %% [raw]
# ls
# cd poster
# ls

# %% [raw]
# ls -la

# %% [raw]
# vim .env

# %% [raw]
# rohit API   GOOGLE_API_KEY= AIzaSyA4aZRpnDEQFkof3KtvuK5XM57kAMVowgk

# %% [raw]
# purushottam GOOGLE_API_KEY=AIzaSyBvdJ9104aK47lgXLNVsIEeNrUEuOxIWVs

# %% [raw]
# click --> i
# GOOGLE_API_KEY= AIzaSyA4aZRpnDEQFkof3KtvuK5XM57kAMVowgk
# DB_HOST=  <database Endpoint paste>
# DB_NAME=postgres
# DB_USER=postgres
# DB_PASSWORD=abcd12345
# DB_PORT=5432
#
# --> Esc --> :wq --> enter

# %% [raw]
# docker build -t query_bot_app .

# %% [raw]
# # Go to database
# scroll down
#     --> Security (VPC security grops ✅ )
#         --> Security group id --> Edit inbound rules ✅ -->
#              --> agar nhi benaya huwa hai to --> PostgreSQL --> TCP --> 5432 --> 0.0.0.0/0

# %% [raw]
# docker images

# %% [raw]
# docker run -d -p 8501:8501 --env-file .env query_bot_app

# %% [raw]
# # Go to EC2
# Scroll Down
#    --> Security
#     -->  Security groups
#        --> Edit inbound rules
#            --> Add rule  --> 8501 --> 0.0.0.0/0 --> save rule

# %% [raw]
# back to EC2
# --> instances  -
# -> Public IPv4 address copy
# --> paste new tab with ____________:8501
# search 5 entry

# %% [raw]
# sudo apt install postgresql-client -y

# %% [raw]
# psql -h <Data base me jaker Endpoint ko paste karna> -U postgres -d postgres -p 5432

# %% [raw]
# password -->
# abcd12345

# %% [markdown]
# # kon konse databse chal rhe hai

# %% [raw]
# SELECT datname FROM pg_database;

# %% [markdown]
# # postgres ke ander switch hone ke liye

# %% [raw]
# \c postgres

# %% [markdown]
# # sari table kon konsi hai

# %%
\dt

# %% [markdown]
# # table ke ander query check karne ke liye

# %% [raw]
# \d query_logs

# %% [markdown]
# # Entery check karne ke liye

# %% [raw]
# SELECT * FROM query_logs;

# %%
# docker image ko ards ke sath me kis tarike connection stablish kiya jata hai

# %%
\+q 
# ya iske alwa ctrl+\ sayed

# %% [raw]
# \q

# %% [raw]
# cd ..

# %% [raw]
# rm -rf poster

# %% [raw]
# ls

# %% [raw]
# exit

# %% [raw]
# exit
# ---> show logout close tab
